# %%
import project_path
import capstone.importers.importers

# %%
capstone.importers.importers.acl_arc_files()
# Out:
# ['/Users/ben/workplace/springboard/springboard-ml/capstone/datasets/acl-arc/txt/pdfbox-0.72/I/I05/I05-2008.txt',
#  '/Users/ben/workplace/springboard/springboard-ml/capstone/datasets/acl-arc/txt/pdfbox-0.72/I/I05/I05-5001.txt',
#  '/Users/ben/workplace/springboard/springboard-ml/capstone/datasets/acl-arc/txt/pdfbox-0.72/I/I05/I05-2020.txt',
#  '/Users/ben/workplace/springboard/springboard-ml/capstone/datasets/acl-arc/txt/pdfbox-0.72/I/I05/I05-2034.txt',
#  '/Users/ben/workplace/springboard/springboard-ml/capstone/datasets/acl-arc/txt/pdfbox-0.72/I/I05/I05-7010.txt',
#  '/Users/ben/workplace/springboard/springboard-ml/capstone/datasets/acl-arc/txt/pdfbox-0.72/I/I05/I05-7004.txt',
#  '/Users/ben/workplace/springboard/springboard-ml/capstone/datasets/acl-arc/txt/pdfbox-0.72/I/I05/I05-7005.txt',
#  '/Users/ben/workplace/springboard/springboard-ml/capstone/datasets/acl-arc/txt/pdfbox-0.72/I/I05/I05-7011.txt',
# ...
