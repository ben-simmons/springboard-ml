# %%
# Topic Modeling and Latent Dirichlet Allocation (LDA) in Python
# https://towardsdatascience.com/topic-modeling-and-latent-dirichlet-allocation-in-python-9bf156893c24
# Susan Li
# May 30, 2018

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/ben/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def lemmatize_stemming(text):
    stemmer = SnowballStemmer('english')
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
def import_files(file_paths):
    documents = []
    for file_path in file_paths:
        with open(file_path, 'r') as f:
            data = f.read()
            documents.append(data)
    return documents

# %%
fp1 = '../datasets/acl-arc/txt/pdfbox-0.72/X/X93/X93-1001.txt'
fp2 = '../datasets/acl-arc/txt/pdfbox-0.72/X/X93/X93-1002.txt'
file_paths = [fp1, fp2]
documents = import_files(file_paths)

# %%
processed_docs = list(map(preprocess, documents))
processed_docs[:10]
# Out:
# [['tipster',
#   'program',
#   'overview',
#   'roberta',
#   'merchant',
#   'depart',
#   'defens',
#   'mead',
#   'rhmerch',
#   'afterlif',
#   'ncsc',
#   'tipster',
#   'phase',
#   'task',
#   'tipster',
#   'phase',
#   'advanc',
#   'state',
#   'languag',
#   'technolog',
#   'document',
#   'detect',
#   'inform',
#   'extract',
#   'document',
#   'detect',
#   'includ',
#   'subtask',
#   'rout',
#   'ning',
#   'static',
#   'queri',
#   'stream',
#   'data',
#   'retriev',
#   'run',
#   'queri',
#   'archiv',
#   'data',
#   'inform',
#   'extract',
#   'technolog',
#   'specifi',
#   'type',
#   'inform',
#   'locat',
#   'free',
#   'text',
#   'extract',
#   'place',
#   'databas',
#   'state',
#   'document',
#   'detect',
#   'tipster',
#   'tipster',
#   'user',
#   'search',
#   'larg',
#   'volum',
#   'data',
#   'queri',
#   'inform',
#   'retriev',
#   'tool',
#   'boolean',
#   'keyword',
#   'search',
#   'system',
#   'develop',
#   'decad',
#   'earlier',
#   'charac',
#   'terist',
#   'boolean',
#   'system',
#   'recal',
#   'user',
#   'lose',
#   'unknown',
#   'quantiti',
#   'use',
#   'inform',
#   'unabl',
#   'retriev',
#   'relev',
#   'document',
#   'precis',
#   'user',
#   'read',
#   'larg',
#   'irrelev',
#   'document',
#   'mistaken',
#   'retriev',
#   'rank',
#   'priorit',
#   'user',
#   'scan',
#   'entir',
#   'list',
#   'retriev',
#   'document',
#   'good',
#   'document',
#   'like',
#   'list',
#   'retriev',
#   'document',
#   'hesin',
#   'exact',
#   'match',
#   'user',
#   'generat',
#   'hand',
#   'vari',
#   'spell',
#   'altern',
#   'word',
#   'choic',
#   'build',
#   'rule',
#   'add',
#   'variant',
#   'hand',
#   'build',
#   'queri',
#   'user',
#   'understand',
#   'work',
#   'syntax',
#   'queri',
#   'order',
#   'document',
#   'detect',
#   'deliver',
#   'phase',
#   'result',
#   'algorithm',
#   'develop',
#   'phase',
#   'tipster',
#   'phase',
#   'prototyp',
#   'system',
#   'build',
#   'give',
#   'user',
#   'document',
#   'detect',
#   'tool',
#   'featur',
#   'tech',
#   'nolog',
#   'develop',
#   'phase',
#   'improv',
#   'recal',
#   'compar',
#   'evalu',
#   'system',
#   'tipster',
#   'trec',
#   'demonstr',
#   'higher',
#   'recal',
#   'relev',
#   'document',
#   'improv',
#   'precisica',
#   'user',
#   'read',
#   'fewer',
#   'useless',
#   'document',
#   'order',
#   'one',
#   'want',
#   'rank',
#   'retriev',
#   'user',
#   'review',
#   'document',
#   'stati',
#   'tical',
#   'rank',
#   'accord',
#   'match',
#   'queri',
#   'improv',
#   'chanc',
#   'document',
#   'near',
#   'queue',
#   'queri',
#   'expans',
#   'user',
#   'automati',
#   'calli',
#   'expand',
#   'queri',
#   'draw',
#   'relev',
#   'ument',
#   'concept',
#   'base',
#   'tool',
#   'tbesauri',
#   'automat',
#   'queri',
#   'generat',
#   'use',
#   'natu',
#   'languag',
#   'descript',
#   'subject',
#   'suppli',
#   'user',
#   'generat',
#   'queri',
#   'state',
#   'inform',
#   'extract',
#   'tipster',
#   'notwithstand',
#   'arpa',
#   'commerci',
#   'support',
#   'develop',
#   'inform',
#   'extract',
#   'technolog',
#   'posit',
#   'impact',
#   'seri',
#   'messag',
#   'understand',
#   'confer',
#   'tipster',
#   'inform',
#   'extract',
#   'appli',
#   'databas',
#   'updat',
#   'task',
#   'larg',
#   'procedur',
#   'manual',
#   'extract',
#   'character',
#   'wide',
#   'varianc',
#   'accuraci',
#   'consist',
#   'databas',
#   'content',
#   'heavi',
#   'labor',
#   'commilan',
#   'continu',
#   'cost',
#   'expenditur',
#   'train',
#   'demand',
#   'difficulti',
#   'port',
#   'domain',
#   'difficulti',
#   'extend',
#   'current',
#   'domain',
#   'deploy',
#   'inform',
#   'extract',
#   'system',
#   'rare',
#   'commerci',
#   'govern',
#   'applic',
#   'system',
#   'character',
#   'lack',
#   'extensibif',
#   'dcanain',
#   'lack',
#   'portabl',
#   'domain',
#   'languag',
#   'depend',
#   'english',
#   'task',
#   'depend',
#   'solv',
#   'singl',
#   'problem',
#   'littl',
#   'reusabl',
#   'high',
#   'develop',
#   'cost',
#   'develop',
#   'mainten',
#   'inform',
#   'extract',
#   'deliver',
#   'phase',
#   'result',
#   'algorithm',
#   'develop',
#   'phase',
#   'tipster',
#   'phase',
#   'prototyp',
#   'system',
#   'build',
#   'follow',
#   'characterist',
#   'increas',
#   'extens',
#   'domain',
#   'reduc',
#   'user',
#   'involv',
#   'greater',
#   'eas',
#   'portabl',
#   'differ',
#   'domain',
#   'languag',
#   'independ',
#   'portabl',
#   'languag',
#   'task',
#   'independ',
#   'solv',
#   'multipl',
#   'problem',
#   'reusabl',
#   'compon',
#   'user',
#   'use',
#   'mainten',
#   'minim',
#   'develop',
#   'involv',
#   'system',
#   'provid',
#   'user',
#   'extract',
#   'tool',
#   'featur',
#   'accur',
#   'consist',
#   'databas',
#   'content',
#   'result',
#   'minim',
#   'user',
#   'intervent',
#   'review',
#   'extract',
#   'result',
#   'initi',
#   'cost',
#   'expenditur',
#   'littl',
#   'mainten',
#   'cost',
#   'flexibl',
#   'manag',
#   'informatien',
#   'act',
#   'appfic',
#   'task',
#   'indic',
#   'warn',
#   'ing',
#   'text',
#   'tag',
#   'document',
#   'detect',
#   'support',
#   'text',
#   'retriev',
#   'confer',
#   'trec',
#   'describ',
#   'document',
#   'detecfien',
#   'section'],
#  ['tipster',
#   'program',
#   'histori',
#   'thoma',
#   'crystal',
#   'advanc',
#   'research',
#   'project',
#   'agenc',
#   'faiffax',
#   'drive',
#   'arlington',
#   'crystal',
#   'arpa',
#   'histori',
#   'tipster',
#   'text',
#   'program',
#   'multipl',
#   'thread',
#   'prepar',
#   'report',
#   'mark',
#   'phase',
#   'phase',
#   'lxogram',
#   'histori',
#   'plan',
#   'ning',
#   'phase',
#   'maintain',
#   'success',
#   'thread',
#   'thread',
#   'close',
#   'cooper',
#   'govern',
#   'ment',
#   'organ',
#   'formul',
#   'implement',
#   'program',
#   'includ',
#   'share',
#   'program',
#   'mulat',
#   'fund',
#   'share',
#   'definit',
#   'task',
#   'prepar',
#   'larg',
#   'text',
#   'corpora',
#   'develop',
#   'develop',
#   'implement',
#   'evalu',
#   'methodolog',
#   'second',
#   'thread',
#   'cooper',
#   'contractor',
#   'share',
#   'idea',
#   'resourc',
#   'pursu',
#   'differ',
#   'petit',
#   'approach',
#   'problem',
#   'text',
#   'process',
#   'thread',
#   'sponsorship',
#   'intern',
#   'messag',
#   'understand',
#   'confer',
#   'text',
#   'retriev',
#   'confer',
#   'trec',
#   'confer',
#   'evalu',
#   'state',
#   'promot',
#   'text',
#   'process',
#   'outsid',
#   'tipster',
#   'text',
#   'contract',
#   'orga',
#   'nize',
#   'nrad',
#   'nist',
#   'preced',
#   'stage',
#   'tipster',
#   'sponsorship',
#   'confer',
#   'program',
#   'formul',
#   'program',
#   'concept',
#   'tipster',
#   'text',
#   'program',
#   'develop',
#   'arpa',
#   'begin',
#   'june',
#   'follow',
#   'promis',
#   'result',
#   'confer',
#   'appreci',
#   'need',
#   'autom',
#   'handl',
#   'larg',
#   'volum',
#   'text',
#   'formul',
#   'text',
#   'cess',
#   'technolog',
#   'develop',
#   'plan',
#   'arpa',
#   'approv',
#   'fund',
#   'program',
#   'take',
#   'risk',
#   'develop',
#   'technolog',
#   'result',
#   'substanti',
#   'bene',
#   'fit',
#   'face',
#   'govern',
#   'grow',
#   'need',
#   'sort',
#   'analyz',
#   'larg',
#   'volum',
#   'text',
#   'begin',
#   'januari',
#   'success',
#   'meet',
#   'hold',
#   'govern',
#   'agenc',
#   'interest',
#   'develop',
#   'ment',
#   'text',
#   'process',
#   'technolog',
#   'come',
#   'agreement',
#   'share',
#   'plan',
#   'fund',
#   'execut',
#   'progran',
#   'signific',
#   'decis',
#   'includ',
#   'have',
#   'program',
#   'phase',
#   'year',
#   'advanc',
#   'algorithm',
#   'follow',
#   'year',
#   'develop',
#   'prototyp',
#   'onstrat',
#   'system',
#   'separ',
#   'focus',
#   'detect',
#   'retriev',
#   'rout',
#   'extract',
#   'understand',
#   'emphasi',
#   'domain',
#   'languag',
#   'portabl',
#   'peri',
#   'odic',
#   'evalu',
#   'complet',
#   'system',
#   'develop',
#   'govern',
#   'larg',
#   'corpora',
#   'train',
#   'test',
#   'corpus',
#   'base',
#   'techniqu',
#   'develop',
#   'eval',
#   'uation',
#   'june',
#   'publish',
#   'solicit',
#   'propos',
#   'particip',
#   'program',
#   'select',
#   'contractor',
#   'investig',
#   'differ',
#   'approach',
#   'detect',
#   'extract',
#   'clarif',
#   'propos',
#   'select',
#   'sourc',
#   'negoti',
#   'tract',
#   'take',
#   'fiscal',
#   'phase',
#   'program',
#   'prior',
#   'begin',
#   'contractor',
#   'work',
#   'govern',
#   'ment',
#   'begin',
#   'intens',
#   'year',
#   'effort',
#   'acquisi',
#   'tion',
#   'prepar',
#   'annot',
#   'corpora',
#   'project',
#   'describ',
#   'separ',
#   'section',
#   'detect',
#   'extrac',
#   'tion',
#   'virtual',
#   'start',
#   'tipster',
#   'text',
#   'phase',
#   'occur',
#   'kickoff',
#   'workshop',
#   'hold',
#   'septemb',
#   'govern',
#   'ment',
#   'review',
#   'framework',
#   'object',
#   'plan',
#   'follow',
#   'year',
#   'work',
#   'contractor',
#   'describ',
#   'specif',
#   'approach',
#   'detect',
#   'extract',
#   'lay',
#   'groundwork',
#   'futur',
#   'share',
#   'idea',
#   'softwar',
#   'data',
#   'resourc',
#   'workshop',
#   'includ',
#   'paral',
#   'work',
#   'session',
#   'discuss',
#   'specif',
#   'issu',
#   'differ',
#   'area',
#   'research',
#   'includ',
#   'detail',
#   'address',
#   'differ',
#   'domain',
#   'differ',
#   'languag',
#   'ernment',
#   'prepar',
#   'data',
#   'workshop',
#   'repeat',
#   'month',
#   'interv',
#   'durat',
#   'phase',
#   'select',
#   'research',
#   'arpa',
#   'human',
#   'languag',
#   'technolog',
#   'program',
#   'invit',
#   'connect',
#   'month',
#   'month',
#   'month',
#   'final',
#   'meet',
#   'uniform',
#   'evalu',
#   'perform',
#   'conduct',
#   'report',
#   'meet',
#   'meet',
#   'frequent',
#   'exchang',
#   'infor',
#   'mation',
#   'govern',
#   'contractor',
#   'heavi',
#   'electron',
#   'mail',
#   'year',
#   'sizabl',
#   'catalog',
#   'shareabl',
#   'resourc',
#   'develop',
#   'avail',
#   'dual',
#   'fund',
#   'permit',
#   'addit',
#   'addit',
#   'detect',
#   'addit',
#   'extract',
#   'tractor',
#   'final',
#   'year',
#   'phase',
#   'tipster',
#   'text',
#   'contractor',
#   'requir',
#   'particip',
#   'trec',
#   'trec',
#   'tipster',
#   'evalu',
#   'techniqu',
#   'hold',
#   'coincid',
#   'final',
#   'phase',
#   'evalu',
#   'provid',
#   'measur',
#   'state',
#   'identifi',
#   'good',
#   'perform',
#   'phase',
#   'ster',
#   'program',
#   'conclud',
#   'month',
#   'workshop',
#   'phase',
#   'plan',
#   'year',
#   'phase',
#   'govern',
#   'begin',
#   'plan',
#   'ning',
#   'phase',
#   'scenario',
#   'develop',
#   'indic',
#   'varieti',
#   'actual',
#   'applic',
#   'system',
#   'devel',
#   'ope',
#   'tier',
#   'program',
#   'continu',
#   'algorithm',
#   'develop',
#   'transfer',
#   'technolog',
#   'demonstra',
#   'tion',
#   'project',
#   'defin',
#   'manag',
#   'phase',
#   'follow',
#   'success',
#   'thread',
#   'phase',
#   'close',
#   'cooper',
#   'govern',
#   'agenc',
#   'contractor',
#   'regular',
#   'workshop',
#   'corpora',
#   'develop',
#   'test',
#   'period',
#   'evalu',
#   'trec',
#   'contin',
#   'increas',
#   'interact',
#   'arpa',
#   'communiti',
#   'contractor',
#   'share',
#   'softwar',
#   'licens',
#   'develop',
#   'communiti',
#   'design',
#   'phase',
#   'system',
#   'analysi',
#   'nario',
#   'indic',
#   'complementari',
#   'natur',
#   'detect',
#   'extract',
#   'oper',
#   'desir',
#   'support',
#   'capabl',
#   'singl',
#   'appear',
#   'similar',
#   'modul',
#   'divers',
#   'system',
#   'determin',
#   'initi',
#   'activ',
#   'phase',
#   'develop',
#   'common',
#   'open',
#   'softwar',
#   'architectur',
#   'implement',
#   'text',
#   'process',
#   'system',
#   'architectur',
#   'facilit',
#   'share',
#   'develop',
#   'task',
#   'transfer',
#   'technolog',
#   'actual',
#   'applic',
#   'futur',
#   'improv',
#   'algorithm',
#   'continu',
#   'upgrad',
#   'system',
#   'architectur',
#   'architectur',
#   'stress',
#   'function',
#   'knowledg',
#   'base',
#   'modular',
#   'sgml',
#   'iik',
#   'languag',
#   'tag',
#   'text',
#   'transfer',
#   'modul',
#   'architectur',
#   'develop',
#   'phase',
#   'cooper',
#   'effort',
#   'multipl',
#   'contractor',
#   'coordin',
#   'independ',
#   'system',
#   'engin',
#   'figur',
#   'manag',
#   'contractor',
#   'contractor',
#   'task',
#   'modul',
#   'architectur',
#   'design',
#   'phase',
#   'includ',
#   'improv',
#   'algorithm',
#   'research',
#   'bin',
#   'result',
#   'applic',
#   'divers',
#   'extract',
#   'detect',
#   'techniqu',
#   'solicit',
#   'propos',
#   'particip',
#   'phase',
#   'issu',
#   'august',
#   'respons',
#   'bidder',
#   'octob',
#   'select',
#   'negoti',
#   'plan',
#   'complet',
#   'work',
#   'begin',
#   'earli',
#   'spring',
#   'bidder',
#   'judg',
#   'potenti',
#   'sourc',
#   'demonstr',
#   'project',
#   'individu',
#   'agenc',
#   'issu',
#   'separ',
#   'project',
#   'project',
#   'demonstr',
#   'base',
#   'architectur',
#   'ule',
#   'develop',
#   'tier',
#   'develop',
#   'instal',
#   'evalu',
#   'process',
#   'actual',
#   'oper',
#   'data',
#   'need',
#   'architectur',
#   'algorithm',
#   'improv',
#   'tional',
#   'research',
#   'project',
#   'procur',
#   'award',
#   'demonstr',
#   'project',
#   'coordin',
#   'develop',
#   'architectur']]

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 accord
# 1 accur
# 2 accuraci
# 3 act
# 4 add
# 5 advanc
# 6 afterlif
# 7 algorithm
# 8 altern
# 9 appfic
# 10 appli

# %%
# Filter
# Uncomment when corpus has more than 15 documents
#dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
bow_corpus[1]
# Out:
# [(5, 2),
#  (7, 5),
#  (11, 3),
#  (13, 5),
#  (16, 3),
#  (29, 1),
#  (30, 5),
#  (33, 2),
#  (36, 3),
#  (43, 3),
#  (47, 2),
#  (50, 7),
#  (51, 20),
#  (52, 5),
#  (55, 2),
#  (61, 8),
#  (69, 6),
#  (73, 4),
#  (77, 1),
#  (78, 9),
#  (81, 1),
#  (86, 3),
#  (87, 5),
#  (88, 1),
#  (89, 1),
#  (90, 2),
#  (94, 1),
#  (101, 4),
#  (102, 4),
#  (109, 2),
#  (114, 1),
#  (117, 2),
#  (121, 2),
#  (127, 20),
#  (130, 1),
#  (135, 1),
#  (137, 14),
#  (138, 1),
#  (139, 1),
#  (149, 3),
#  (150, 2),
#  (152, 1),
#  (155, 1),
#  (160, 1),
#  (162, 1),
#  (166, 2),
#  (173, 1),
#  (175, 8),
#  (176, 1),
#  (177, 3),
#  (180, 6),
#  (182, 15),
#  (184, 8),
#  (186, 1),
#  (187, 4),
#  (191, 2),
#  (200, 2),
#  (205, 4),
#  (206, 1),
#  (207, 1),
#  (208, 3),
#  (209, 3),
#  (210, 1),
#  (211, 4),
#  (212, 1),
#  (213, 1),
#  (214, 1),
#  (215, 1),
#  (216, 1),
#  (217, 1),
#  (218, 3),
#  (219, 1),
#  (220, 9),
#  (221, 1),
#  (222, 1),
#  (223, 1),
#  (224, 1),
#  (225, 1),
#  (226, 1),
#  (227, 6),
#  (228, 1),
#  (229, 2),
#  (230, 1),
#  (231, 1),
#  (232, 1),
#  (233, 1),
#  (234, 1),
#  (235, 2),
#  (236, 1),
#  (237, 1),
#  (238, 1),
#  (239, 2),
#  (240, 1),
#  (241, 2),
#  (242, 1),
#  (243, 1),
#  (244, 1),
#  (245, 1),
#  (246, 1),
#  (247, 11),
#  (248, 4),
#  (249, 2),
#  (250, 4),
#  (251, 1),
#  (252, 2),
#  (253, 1),
#  (254, 1),
#  (255, 1),
#  (256, 1),
#  (257, 2),
#  (258, 1),
#  (259, 1),
#  (260, 1),
#  (261, 1),
#  (262, 1),
#  (263, 2),
#  (264, 1),
#  (265, 1),
#  (266, 1),
#  (267, 1),
#  (268, 2),
#  (269, 1),
#  (270, 1),
#  (271, 1),
#  (272, 1),
#  (273, 1),
#  (274, 1),
#  (275, 1),
#  (276, 1),
#  (277, 1),
#  (278, 1),
#  (279, 1),
#  (280, 1),
#  (281, 3),
#  (282, 1),
#  (283, 1),
#  (284, 1),
#  (285, 3),
#  (286, 1),
#  (287, 1),
#  (288, 1),
#  (289, 4),
#  (290, 2),
#  (291, 1),
#  (292, 1),
#  (293, 1),
#  (294, 1),
#  (295, 3),
#  (296, 3),
#  (297, 1),
#  (298, 2),
#  (299, 1),
#  (300, 1),
#  (301, 3),
#  (302, 1),
#  (303, 1),
#  (304, 1),
#  (305, 1),
#  (306, 1),
#  (307, 1),
#  (308, 1),
#  (309, 1),
#  (310, 1),
#  (311, 1),
#  (312, 3),
#  (313, 1),
#  (314, 1),
#  (315, 2),
#  (316, 1),
#  (317, 1),
#  (318, 1),
#  (319, 1),
#  (320, 1),
#  (321, 1),
#  (322, 1),
#  (323, 1),
#  (324, 1),
#  (325, 1),
#  (326, 4),
#  (327, 4),
#  (328, 1),
#  (329, 3),
#  (330, 1),
#  (331, 5),
#  (332, 1),
#  (333, 1),
#  (334, 1),
#  (335, 3),
#  (336, 2),
#  (337, 1),
#  (338, 1),
#  (339, 1),
#  (340, 1),
#  (341, 1),
#  (342, 1),
#  (343, 1),
#  (344, 1),
#  (345, 1),
#  (346, 1),
#  (347, 2),
#  (348, 1),
#  (349, 1),
#  (350, 1),
#  (351, 1),
#  (352, 3),
#  (353, 2),
#  (354, 1),
#  (355, 1),
#  (356, 1),
#  (357, 1),
#  (358, 7),
#  (359, 1),
#  (360, 1),
#  (361, 4),
#  (362, 1),
#  (363, 5),
#  (364, 1),
#  (365, 1),
#  (366, 8),
#  (367, 1),
#  (368, 1),
#  (369, 3),
#  (370, 1),
#  (371, 1),
#  (372, 1),
#  (373, 1),
#  (374, 2),
#  (375, 1),
#  (376, 5),
#  (377, 3),
#  (378, 1),
#  (379, 1),
#  (380, 1),
#  (381, 1),
#  (382, 4),
#  (383, 3),
#  (384, 1),
#  (385, 1),
#  (386, 1),
#  (387, 7),
#  (388, 1),
#  (389, 1),
#  (390, 1),
#  (391, 1),
#  (392, 3),
#  (393, 2),
#  (394, 1),
#  (395, 2),
#  (396, 2),
#  (397, 2),
#  (398, 1),
#  (399, 1),
#  (400, 1),
#  (401, 1),
#  (402, 1),
#  (403, 1),
#  (404, 3),
#  (405, 2),
#  (406, 3),
#  (407, 2),
#  (408, 1),
#  (409, 6),
#  (410, 2),
#  (411, 3),
#  (412, 1),
#  (413, 1),
#  (414, 1),
#  (415, 3),
#  (416, 1),
#  (417, 1),
#  (418, 1),
#  (419, 1),
#  (420, 1),
#  (421, 1),
#  (422, 5),
#  (423, 7)]

# %%
# Sample bag of words for a preprocessed document
bow_doc_1 = bow_corpus[1]
for i in range(len(bow_doc_1)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_1[i][0], 
                                               dictionary[bow_doc_1[i][0]], 
bow_doc_1[i][1]))
# Out:
# Word 5 ("advanc") appears 2 time.
# Word 7 ("algorithm") appears 5 time.
# Word 11 ("applic") appears 3 time.
# Word 13 ("arpa") appears 5 time.
# Word 16 ("base") appears 3 time.
# Word 29 ("concept") appears 1 time.
# Word 30 ("confer") appears 5 time.
# Word 33 ("continu") appears 2 time.
# Word 36 ("data") appears 3 time.
# Word 43 ("demonstr") appears 3 time.
# Word 47 ("describ") appears 2 time.
# Word 50 ("detect") appears 7 time.
# Word 51 ("develop") appears 20 time.
# Word 52 ("differ") appears 5 time.
# Word 55 ("domain") appears 2 time.
# Word 61 ("evalu") appears 8 time.
# Word 69 ("extract") appears 6 time.
# Word 73 ("follow") appears 4 time.
# Word 77 ("good") appears 1 time.
# Word 78 ("govern") appears 9 time.
# Word 81 ("heavi") appears 1 time.
# Word 86 ("improv") appears 3 time.
# Word 87 ("includ") appears 5 time.
# Word 88 ("increas") appears 1 time.
# Word 89 ("independ") appears 1 time.
# Word 90 ("indic") appears 2 time.
# Word 94 ("initi") appears 1 time.
# Word 101 ("languag") appears 4 time.
# Word 102 ("larg") appears 4 time.
# Word 109 ("manag") appears 2 time.
# Word 114 ("messag") appears 1 time.
# Word 117 ("multipl") appears 2 time.
# Word 121 ("ning") appears 2 time.
# Word 127 ("phase") appears 20 time.
# Word 130 ("portabl") appears 1 time.
# Word 135 ("problem") appears 1 time.
# Word 137 ("program") appears 14 time.
# Word 138 ("prototyp") appears 1 time.
# Word 139 ("provid") appears 1 time.
# Word 149 ("result") appears 3 time.
# Word 150 ("retriev") appears 2 time.
# Word 152 ("review") appears 1 time.
# Word 155 ("rout") appears 1 time.
# Word 160 ("section") appears 1 time.
# Word 162 ("singl") appears 1 time.
# Word 166 ("state") appears 2 time.
# Word 173 ("support") appears 1 time.
# Word 175 ("system") appears 8 time.
# Word 176 ("tag") appears 1 time.
# Word 177 ("task") appears 3 time.
# Word 180 ("technolog") appears 6 time.
# Word 182 ("text") appears 15 time.
# Word 184 ("tipster") appears 8 time.
# Word 186 ("train") appears 1 time.
# Word 187 ("trec") appears 4 time.
# Word 191 ("understand") appears 2 time.
# Word 200 ("volum") appears 2 time.
# Word 205 ("work") appears 4 time.
# Word 206 ("acquisi") appears 1 time.
# Word 207 ("activ") appears 1 time.
# Word 208 ("actual") appears 3 time.
# Word 209 ("addit") appears 3 time.
# Word 210 ("address") appears 1 time.
# Word 211 ("agenc") appears 4 time.
# Word 212 ("agreement") appears 1 time.
# Word 213 ("analysi") appears 1 time.
# Word 214 ("analyz") appears 1 time.
# Word 215 ("annot") appears 1 time.
# Word 216 ("appear") appears 1 time.
# Word 217 ("appreci") appears 1 time.
# Word 218 ("approach") appears 3 time.
# Word 219 ("approv") appears 1 time.
# Word 220 ("architectur") appears 9 time.
# Word 221 ("area") appears 1 time.
# Word 222 ("arlington") appears 1 time.
# Word 223 ("august") appears 1 time.
# Word 224 ("autom") appears 1 time.
# Word 225 ("avail") appears 1 time.
# Word 226 ("award") appears 1 time.
# Word 227 ("begin") appears 6 time.
# Word 228 ("bene") appears 1 time.
# Word 229 ("bidder") appears 2 time.
# Word 230 ("bin") appears 1 time.
# Word 231 ("capabl") appears 1 time.
# Word 232 ("catalog") appears 1 time.
# Word 233 ("cess") appears 1 time.
# Word 234 ("clarif") appears 1 time.
# Word 235 ("close") appears 2 time.
# Word 236 ("coincid") appears 1 time.
# Word 237 ("come") appears 1 time.
# Word 238 ("common") appears 1 time.
# Word 239 ("communiti") appears 2 time.
# Word 240 ("complementari") appears 1 time.
# Word 241 ("complet") appears 2 time.
# Word 242 ("conclud") appears 1 time.
# Word 243 ("conduct") appears 1 time.
# Word 244 ("connect") appears 1 time.
# Word 245 ("contin") appears 1 time.
# Word 246 ("contract") appears 1 time.
# Word 247 ("contractor") appears 11 time.
# Word 248 ("cooper") appears 4 time.
# Word 249 ("coordin") appears 2 time.
# Word 250 ("corpora") appears 4 time.
# Word 251 ("corpus") appears 1 time.
# Word 252 ("crystal") appears 2 time.
# Word 253 ("decis") appears 1 time.
# Word 254 ("defin") appears 1 time.
# Word 255 ("definit") appears 1 time.
# Word 256 ("demonstra") appears 1 time.
# Word 257 ("design") appears 2 time.
# Word 258 ("desir") appears 1 time.
# Word 259 ("detail") appears 1 time.
# Word 260 ("determin") appears 1 time.
# Word 261 ("devel") appears 1 time.
# Word 262 ("discuss") appears 1 time.
# Word 263 ("divers") appears 2 time.
# Word 264 ("drive") appears 1 time.
# Word 265 ("dual") appears 1 time.
# Word 266 ("durat") appears 1 time.
# Word 267 ("earli") appears 1 time.
# Word 268 ("effort") appears 2 time.
# Word 269 ("electron") appears 1 time.
# Word 270 ("emphasi") appears 1 time.
# Word 271 ("engin") appears 1 time.
# Word 272 ("ernment") appears 1 time.
# Word 273 ("eval") appears 1 time.
# Word 274 ("exchang") appears 1 time.
# Word 275 ("execut") appears 1 time.
# Word 276 ("extrac") appears 1 time.
# Word 277 ("face") appears 1 time.
# Word 278 ("facilit") appears 1 time.
# Word 279 ("faiffax") appears 1 time.
# Word 280 ("figur") appears 1 time.
# Word 281 ("final") appears 3 time.
# Word 282 ("fiscal") appears 1 time.
# Word 283 ("fit") appears 1 time.
# Word 284 ("focus") appears 1 time.
# Word 285 ("formul") appears 3 time.
# Word 286 ("framework") appears 1 time.
# Word 287 ("frequent") appears 1 time.
# Word 288 ("function") appears 1 time.
# Word 289 ("fund") appears 4 time.
# Word 290 ("futur") appears 2 time.
# Word 291 ("groundwork") appears 1 time.
# Word 292 ("grow") appears 1 time.
# Word 293 ("handl") appears 1 time.
# Word 294 ("have") appears 1 time.
# Word 295 ("histori") appears 3 time.
# Word 296 ("hold") appears 3 time.
# Word 297 ("human") appears 1 time.
# Word 298 ("idea") appears 2 time.
# Word 299 ("identifi") appears 1 time.
# Word 300 ("iik") appears 1 time.
# Word 301 ("implement") appears 3 time.
# Word 302 ("individu") appears 1 time.
# Word 303 ("infor") appears 1 time.
# Word 304 ("instal") appears 1 time.
# Word 305 ("intens") appears 1 time.
# Word 306 ("interact") appears 1 time.
# Word 307 ("interest") appears 1 time.
# Word 308 ("intern") appears 1 time.
# Word 309 ("interv") appears 1 time.
# Word 310 ("investig") appears 1 time.
# Word 311 ("invit") appears 1 time.
# Word 312 ("issu") appears 3 time.
# Word 313 ("januari") appears 1 time.
# Word 314 ("judg") appears 1 time.
# Word 315 ("june") appears 2 time.
# Word 316 ("kickoff") appears 1 time.
# Word 317 ("knowledg") appears 1 time.
# Word 318 ("lay") appears 1 time.
# Word 319 ("licens") appears 1 time.
# Word 320 ("lxogram") appears 1 time.
# Word 321 ("mail") appears 1 time.
# Word 322 ("maintain") appears 1 time.
# Word 323 ("mark") appears 1 time.
# Word 324 ("mation") appears 1 time.
# Word 325 ("measur") appears 1 time.
# Word 326 ("meet") appears 4 time.
# Word 327 ("ment") appears 4 time.
# Word 328 ("methodolog") appears 1 time.
# Word 329 ("modul") appears 3 time.
# Word 330 ("modular") appears 1 time.
# Word 331 ("month") appears 5 time.
# Word 332 ("mulat") appears 1 time.
# Word 333 ("nario") appears 1 time.
# Word 334 ("natur") appears 1 time.
# Word 335 ("need") appears 3 time.
# Word 336 ("negoti") appears 2 time.
# Word 337 ("nist") appears 1 time.
# Word 338 ("nize") appears 1 time.
# Word 339 ("nrad") appears 1 time.
# Word 340 ("object") appears 1 time.
# Word 341 ("occur") appears 1 time.
# Word 342 ("octob") appears 1 time.
# Word 343 ("odic") appears 1 time.
# Word 344 ("onstrat") appears 1 time.
# Word 345 ("ope") appears 1 time.
# Word 346 ("open") appears 1 time.
# Word 347 ("oper") appears 2 time.
# Word 348 ("orga") appears 1 time.
# Word 349 ("organ") appears 1 time.
# Word 350 ("outsid") appears 1 time.
# Word 351 ("paral") appears 1 time.
# Word 352 ("particip") appears 3 time.
# Word 353 ("perform") appears 2 time.
# Word 354 ("peri") appears 1 time.
# Word 355 ("period") appears 1 time.
# Word 356 ("permit") appears 1 time.
# Word 357 ("petit") appears 1 time.
# Word 358 ("plan") appears 7 time.
# Word 359 ("potenti") appears 1 time.
# Word 360 ("preced") appears 1 time.
# Word 361 ("prepar") appears 4 time.
# Word 362 ("prior") appears 1 time.
# Word 363 ("process") appears 5 time.
# Word 364 ("procur") appears 1 time.
# Word 365 ("progran") appears 1 time.
# Word 366 ("project") appears 8 time.
# Word 367 ("promis") appears 1 time.
# Word 368 ("promot") appears 1 time.
# Word 369 ("propos") appears 3 time.
# Word 370 ("publish") appears 1 time.
# Word 371 ("pursu") appears 1 time.
# Word 372 ("regular") appears 1 time.
# Word 373 ("repeat") appears 1 time.
# Word 374 ("report") appears 2 time.
# Word 375 ("requir") appears 1 time.
# Word 376 ("research") appears 5 time.
# Word 377 ("resourc") appears 3 time.
# Word 378 ("respons") appears 1 time.
# Word 379 ("risk") appears 1 time.
# Word 380 ("scenario") appears 1 time.
# Word 381 ("second") appears 1 time.
# Word 382 ("select") appears 4 time.
# Word 383 ("separ") appears 3 time.
# Word 384 ("septemb") appears 1 time.
# Word 385 ("session") appears 1 time.
# Word 386 ("sgml") appears 1 time.
# Word 387 ("share") appears 7 time.
# Word 388 ("shareabl") appears 1 time.
# Word 389 ("signific") appears 1 time.
# Word 390 ("similar") appears 1 time.
# Word 391 ("sizabl") appears 1 time.
# Word 392 ("softwar") appears 3 time.
# Word 393 ("solicit") appears 2 time.
# Word 394 ("sort") appears 1 time.
# Word 395 ("sourc") appears 2 time.
# Word 396 ("specif") appears 2 time.
# Word 397 ("sponsorship") appears 2 time.
# Word 398 ("spring") appears 1 time.
# Word 399 ("stage") appears 1 time.
# Word 400 ("start") appears 1 time.
# Word 401 ("ster") appears 1 time.
# Word 402 ("stress") appears 1 time.
# Word 403 ("substanti") appears 1 time.
# Word 404 ("success") appears 3 time.
# Word 405 ("take") appears 2 time.
# Word 406 ("techniqu") appears 3 time.
# Word 407 ("test") appears 2 time.
# Word 408 ("thoma") appears 1 time.
# Word 409 ("thread") appears 6 time.
# Word 410 ("tier") appears 2 time.
# Word 411 ("tion") appears 3 time.
# Word 412 ("tional") appears 1 time.
# Word 413 ("tract") appears 1 time.
# Word 414 ("tractor") appears 1 time.
# Word 415 ("transfer") appears 3 time.
# Word 416 ("uation") appears 1 time.
# Word 417 ("ule") appears 1 time.
# Word 418 ("uniform") appears 1 time.
# Word 419 ("upgrad") appears 1 time.
# Word 420 ("varieti") appears 1 time.
# Word 421 ("virtual") appears 1 time.
# Word 422 ("workshop") appears 5 time.
# Word 423 ("year") appears 7 time.

# %%
# TF-IDF
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.03163859985841663),
#  (1, 0.03163859985841663),
#  (2, 0.03163859985841663),
#  (3, 0.03163859985841663),
#  (4, 0.03163859985841663),
#  (6, 0.03163859985841663),
#  (8, 0.03163859985841663),
#  (9, 0.03163859985841663),
#  (10, 0.03163859985841663),
#  (12, 0.03163859985841663),
#  (14, 0.03163859985841663),
#  (15, 0.03163859985841663),
#  (17, 0.06327719971683327),
#  (18, 0.12655439943366653),
#  (19, 0.03163859985841663),
#  (20, 0.03163859985841663),
#  (21, 0.03163859985841663),
#  (22, 0.06327719971683327),
#  (23, 0.03163859985841663),
#  (24, 0.03163859985841663),
#  (25, 0.06327719971683327),
#  (26, 0.03163859985841663),
#  (27, 0.03163859985841663),
#  (28, 0.03163859985841663),
#  (31, 0.06327719971683327),
#  (32, 0.06327719971683327),
#  (34, 0.12655439943366653),
#  (35, 0.03163859985841663),
#  (37, 0.12655439943366653),
#  (38, 0.03163859985841663),
#  (39, 0.03163859985841663),
#  (40, 0.03163859985841663),
#  (41, 0.06327719971683327),
#  (42, 0.03163859985841663),
#  (44, 0.03163859985841663),
#  (45, 0.06327719971683327),
#  (46, 0.03163859985841663),
#  (48, 0.03163859985841663),
#  (49, 0.03163859985841663),
#  (53, 0.06327719971683327),
#  (54, 0.5062175977346661),
#  (56, 0.03163859985841663),
#  (57, 0.03163859985841663),
#  (58, 0.03163859985841663),
#  (59, 0.03163859985841663),
#  (60, 0.03163859985841663),
#  (62, 0.03163859985841663),
#  (63, 0.03163859985841663),
#  (64, 0.03163859985841663),
#  (65, 0.06327719971683327),
#  (66, 0.03163859985841663),
#  (67, 0.03163859985841663),
#  (68, 0.03163859985841663),
#  (70, 0.06327719971683327),
#  (71, 0.03163859985841663),
#  (72, 0.03163859985841663),
#  (74, 0.03163859985841663),
#  (75, 0.0949157995752499),
#  (76, 0.03163859985841663),
#  (79, 0.03163859985841663),
#  (80, 0.06327719971683327),
#  (82, 0.03163859985841663),
#  (83, 0.03163859985841663),
#  (84, 0.03163859985841663),
#  (85, 0.03163859985841663),
#  (91, 0.31638599858416633),
#  (92, 0.03163859985841663),
#  (93, 0.03163859985841663),
#  (95, 0.03163859985841663),
#  (96, 0.06327719971683327),
#  (97, 0.03163859985841663),
#  (98, 0.03163859985841663),
#  (99, 0.03163859985841663),
#  (100, 0.06327719971683327),
#  (103, 0.03163859985841663),
#  (104, 0.06327719971683327),
#  (105, 0.06327719971683327),
#  (106, 0.03163859985841663),
#  (107, 0.03163859985841663),
#  (108, 0.0949157995752499),
#  (110, 0.03163859985841663),
#  (111, 0.06327719971683327),
#  (112, 0.03163859985841663),
#  (113, 0.03163859985841663),
#  (115, 0.06327719971683327),
#  (116, 0.03163859985841663),
#  (118, 0.03163859985841663),
#  (119, 0.03163859985841663),
#  (120, 0.03163859985841663),
#  (122, 0.03163859985841663),
#  (123, 0.03163859985841663),
#  (124, 0.03163859985841663),
#  (125, 0.06327719971683327),
#  (126, 0.03163859985841663),
#  (128, 0.03163859985841663),
#  (129, 0.03163859985841663),
#  (131, 0.03163859985841663),
#  (132, 0.03163859985841663),
#  (133, 0.03163859985841663),
#  (134, 0.03163859985841663),
#  (136, 0.03163859985841663),
#  (140, 0.03163859985841663),
#  (141, 0.31638599858416633),
#  (142, 0.03163859985841663),
#  (143, 0.0949157995752499),
#  (144, 0.03163859985841663),
#  (145, 0.06327719971683327),
#  (146, 0.0949157995752499),
#  (147, 0.03163859985841663),
#  (148, 0.0949157995752499),
#  (151, 0.06327719971683327),
#  (153, 0.03163859985841663),
#  (154, 0.03163859985841663),
#  (156, 0.03163859985841663),
#  (157, 0.03163859985841663),
#  (158, 0.03163859985841663),
#  (159, 0.06327719971683327),
#  (161, 0.03163859985841663),
#  (163, 0.06327719971683327),
#  (164, 0.03163859985841663),
#  (165, 0.03163859985841663),
#  (167, 0.03163859985841663),
#  (168, 0.03163859985841663),
#  (169, 0.03163859985841663),
#  (170, 0.03163859985841663),
#  (171, 0.03163859985841663),
#  (172, 0.03163859985841663),
#  (174, 0.03163859985841663),
#  (178, 0.03163859985841663),
#  (179, 0.03163859985841663),
#  (181, 0.03163859985841663),
#  (183, 0.03163859985841663),
#  (185, 0.12655439943366653),
#  (188, 0.03163859985841663),
#  (189, 0.03163859985841663),
#  (190, 0.03163859985841663),
#  (192, 0.03163859985841663),
#  (193, 0.03163859985841663),
#  (194, 0.0949157995752499),
#  (195, 0.03163859985841663),
#  (196, 0.4745789978762495),
#  (197, 0.03163859985841663),
#  (198, 0.03163859985841663),
#  (199, 0.03163859985841663),
#  (201, 0.03163859985841663),
#  (202, 0.03163859985841663),
#  (203, 0.03163859985841663),
#  (204, 0.03163859985841663)]

# %%
# Running LDA using bag of words
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=2, workers=2)
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.015*"phase" + 0.015*"develop" + 0.009*"extract" + 0.009*"tipster" + 0.009*"program" + 0.008*"system" + 0.008*"text" + 0.007*"contractor" + 0.006*"user" + 0.006*"detect"
# Topic: 1
# Words: 0.011*"develop" + 0.010*"phase" + 0.009*"text" + 0.006*"system" + 0.006*"tipster" + 0.006*"contractor" + 0.006*"document" + 0.005*"govern" + 0.005*"extract" + 0.005*"detect"
# Topic: 2
# Words: 0.013*"extract" + 0.013*"user" + 0.011*"document" + 0.011*"phase" + 0.011*"develop" + 0.010*"tipster" + 0.008*"system" + 0.007*"inform" + 0.007*"retriev" + 0.007*"text"
# Topic: 3
# Words: 0.007*"text" + 0.007*"phase" + 0.006*"develop" + 0.005*"program" + 0.005*"system" + 0.005*"architectur" + 0.005*"extract" + 0.004*"tipster" + 0.004*"project" + 0.004*"detect"
# Topic: 4
# Words: 0.015*"document" + 0.014*"user" + 0.014*"tipster" + 0.013*"phase" + 0.012*"develop" + 0.011*"system" + 0.010*"extract" + 0.010*"inform" + 0.007*"queri" + 0.007*"text"
# Topic: 5
# Words: 0.013*"develop" + 0.012*"phase" + 0.009*"user" + 0.008*"extract" + 0.007*"program" + 0.007*"tipster" + 0.007*"text" + 0.006*"detect" + 0.006*"system" + 0.006*"document"
# Topic: 6
# Words: 0.011*"develop" + 0.010*"phase" + 0.008*"extract" + 0.008*"text" + 0.007*"system" + 0.007*"program" + 0.007*"tipster" + 0.006*"document" + 0.006*"user" + 0.006*"detect"
# Topic: 7
# Words: 0.013*"develop" + 0.010*"phase" + 0.008*"text" + 0.007*"program" + 0.007*"detect" + 0.006*"system" + 0.006*"tipster" + 0.006*"evalu" + 0.006*"extract" + 0.006*"contractor"
# Topic: 8
# Words: 0.031*"develop" + 0.030*"phase" + 0.023*"text" + 0.021*"program" + 0.017*"contractor" + 0.014*"govern" + 0.014*"architectur" + 0.013*"tipster" + 0.012*"project" + 0.012*"system"
# Topic: 9
# Words: 0.034*"document" + 0.031*"user" + 0.023*"extract" + 0.022*"phase" + 0.022*"tipster" + 0.022*"queri" + 0.022*"inform" + 0.018*"develop" + 0.018*"system" + 0.017*"retriev"

# %%
# Running LDA using TD-IDF
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.010*"document" + 0.009*"user" + 0.007*"contractor" + 0.007*"inform" + 0.007*"queri" + 0.006*"architectur" + 0.006*"project" + 0.005*"plan" + 0.005*"share" + 0.005*"year"
# Topic: 1 Word: 0.002*"document" + 0.002*"queri" + 0.002*"user" + 0.002*"inform" + 0.002*"year" + 0.002*"architectur" + 0.002*"share" + 0.002*"project" + 0.002*"contractor" + 0.002*"plan"
# Topic: 2 Word: 0.002*"document" + 0.002*"user" + 0.002*"inform" + 0.002*"queri" + 0.002*"contractor" + 0.002*"share" + 0.002*"year" + 0.002*"cost" + 0.002*"build" + 0.002*"architectur"
# Topic: 3 Word: 0.002*"user" + 0.002*"inform" + 0.002*"document" + 0.002*"queri" + 0.002*"contractor" + 0.002*"year" + 0.002*"architectur" + 0.002*"share" + 0.002*"plan" + 0.002*"build"
# Topic: 4 Word: 0.002*"document" + 0.002*"user" + 0.002*"queri" + 0.002*"contractor" + 0.002*"inform" + 0.002*"architectur" + 0.002*"share" + 0.002*"project" + 0.002*"relev" + 0.002*"year"
# Topic: 5 Word: 0.002*"document" + 0.002*"user" + 0.002*"queri" + 0.002*"inform" + 0.002*"contractor" + 0.002*"project" + 0.002*"share" + 0.002*"architectur" + 0.002*"thread" + 0.002*"year"
# Topic: 6 Word: 0.002*"document" + 0.002*"user" + 0.002*"queri" + 0.002*"inform" + 0.002*"year" + 0.002*"contractor" + 0.002*"share" + 0.002*"project" + 0.002*"plan" + 0.002*"cost"
# Topic: 7 Word: 0.002*"document" + 0.002*"queri" + 0.002*"user" + 0.002*"inform" + 0.002*"contractor" + 0.002*"project" + 0.002*"cost" + 0.002*"year" + 0.002*"architectur" + 0.002*"databas"
# Topic: 8 Word: 0.002*"document" + 0.002*"user" + 0.002*"queri" + 0.002*"inform" + 0.002*"architectur" + 0.002*"year" + 0.002*"tool" + 0.002*"share" + 0.002*"plan" + 0.002*"contractor"
# Topic: 9 Word: 0.002*"inform" + 0.002*"user" + 0.002*"document" + 0.002*"queri" + 0.002*"architectur" + 0.002*"contractor" + 0.002*"project" + 0.002*"share" + 0.002*"cost" + 0.002*"relev"
